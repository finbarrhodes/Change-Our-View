# %% [markdown]
# # Notebook 03 – Feature Extraction
# *This notebook enriches the CMV post dataset with structural and linguistic   features that may influence persuasion.*
#
# > **Goal in one line:** extract interpretable, distributed features—like pronoun use, sentiment, readability, and evidence signals—that help model what makes an argument persuasive.

# %% [markdown]
# ### Import statements

# %%
# Standard library
import re

# NLP Processing
from nltk.corpus import stopwords, words
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# PySpark Core
from pyspark.sql import SparkSession
from pyspark.sql.types import (
    StructType, StructField, StringType, 
    IntegerType, BooleanType, ArrayType,
    LongType, FloatType
)

# PySpark Functions
from pyspark.sql.functions import (
    from_unixtime, year, month, date_format,
    udf, col, size, split, when, lit,
    concat_ws
)

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('words')

stop_words = set(stopwords.words('english'))
english_words = set(words.words())
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /usr/local/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/local/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /usr/local/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to /usr/local/share/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %% [markdown]
# ## 1 – Data preprocessing

# %%
# Define schema following Notebook 02
schema_three = StructType([
    StructField("num_comments", IntegerType(), True),    # Number of comments on the post
    StructField("score", IntegerType(), True),           # Reddit score (upvotes - downvotes)
    StructField("delta", BooleanType(), True),           # Whether the post received a delta (changed view)
    StructField("urls", ArrayType(StringType()), True),  # URLs mentioned in the post
    StructField("processed", ArrayType(StringType()), True),  # Preprocessed tokens
    StructField("merged", StringType(), True),           # Merged text field (likely title + selftext)
    StructField("year_month", StringType(), True)        # Time period for temporal analysis
    StructField("category_title",StringType(),True),     # Interpretable category title
    StructField("title", StringType(), True),            # Title of the post
    StructField("selftext", StringType(), True),         # Body text of the post
])

# Read preprocessed data from Bucket
n2_categorized = spark.read.schema(schema_three).json("gs://st446-cmv/n2_categorized_df")
n2_categorized.show(5, truncate=False)
# Out:
# +------------+-----+-----+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |num_comments|score|delta|urls       |processed                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |merged                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# +------------+-----+-----+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |1           |1    |false|[]         |["apple","product","far","superior","product"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              | I believe that Apple products are far superior to Microsoft products. CMV.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# |2           |2    |false|[imgur.com]|["every","single","year","possibly","anything","left","pinkify","next","year","role","around","another","master","marketing","find","else","wrong","guy","pink","shirt","dislike","color","pink","stop","year","pink","flag","referee","wonder","possibly","left","pinkify","well","today","given","prescription","taken","pink","breast","cancer","awareness","far"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |Every single year I think to myself, "There couldn't possibly be anything left to 'pinkify'." but then the next year roles around and another master of marketing finds something else . Don't get me wrong, I'm a guy that has many "pink" shirts, so it's not that I dislike the color pink. It's just when will it stop? This year it was the pink flags that the NFL Referees are using now. After that I began to wonder, "What could possibly be left for them to 'pinkify' now?". Well, today I was given this. Here is my [Walgreens prescription bottle.](http://imgur.com/bVfhW5E) CMV I Believe We Have Taken PINK for Breast Cancer Awareness Too Far                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# |44          |22   |false|[]         |["instance","girl","complain","guy","check","saying","pig","thats","human","instinct","judge","attractiveness","woman","doe","totally","fine","let","clear","course","equality","sex","focus","assume","men","guy","hold","open","door","cause","weak","nice","feminism","take","unfair","men","consideration","custody","child","abuse","whether","physical","verbal","towards","men","feminist","men","focus","enough","actual","problem"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |For instance, girls complain when guys check them out saying we're pigs, when that's just human instinct, to judge attractiveness and when a woman does it, it's totally fine. Let me make it clear, I am of course for equality of the sexes, I just think feminists(not all) should focus on other things and not assume things about what men do, like think that when a guy holds open the door for her that he's coddling her cause she's "too weak". As if they can't just be being nice. Also, I think feminism should also take some things unfair to men into consideration such as custody of children and abuse, whether physical or verbal, towards men. CMV I believe many feminists look way too much into things men do and dont focus enough on actual problems. CMV                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# |30          |22   |false|[]         |["everyone","already","sex","sex","default","option","person","natural","urge","urge","sex","stop","happening","whole","purity","culture","making","ashamed","natural","urge","stop","happening","logical","teach","safely","avoid","pregnancy","decide","theyre","teaching","abstinence","instead","safe","sex","high","school","health","class","useless","ridiculous","asinine"]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |Everyone already knows that they can not have sex. Not having sex is the default option for a person. But one of the strongest (if not THE strongest) natural urge we have is the urge to have sex. You're not going to stop it from happening, even with this whole christian purity culture bullshit making kids ashamed of their natural urges you cant stop it from happening.\n\nThe only logical thing to do is to teach people how to do it safely and avoid pregnancy if/when they decide they're going to do it.\n\n CMV: Teaching abstinence instead of safe sex in high school health class is useless and to me, ridiculous and asinine.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# |36          |0    |false|[]         |["ill","move","argument","forward","backwards","explain","better","thought","big","argument","friend","art","culture","useless","communication","degree","music","conservatoire","trumpet","play","music","instrument","worked","corporate","identity","teacher","graphic","design","journalism","advertising","feeling","van","artist","lot","useless","information","course","shouldnt","denigrate","artist","actually","knowing","creation","doesnt","happier","study","culture","literature","novel","poetry","plastic","art","music","culture","made","artist","express","feeling","rant","money","maybe","done","tree","rock","business","book","non","fictional","whenever","doe","important","fact","person","laugh","disdain","cringe","doe","towards","life","existence","happiness","information","artist","writer","painter","useless","better","knowing","sport","number","tile","street","pretty","clear","culture","great","artist","happy","live","plenty","nature","beloved","counterpoint","friend","learn","whatever","art","doe","done","natural","better","harder","need","manufacture","fake","feeling","naturally","felt","true","relationship","friendship","love","staring","mountain","culture","whole","artificial","counterpoint","influence","physical","design","useful","stuff","building","decoration","yeah","stuff","avoid","racism","art","art","design","argument","influence","doesnt","mean","influence","necessary","expressly","good","design","drug","hit","head","wall","doe","influence","stuff","affect","rainy","day","solar","storm","inspiration","need","listen","creative","music","inspired","create","nice","table","design","good","counterpoint","art","yes","enjoy","killing","watching","lion","eat","little","gazelle","avoid","art","avoid","sport","need","need","give","money","shouldnt","movie","game","painting","comic","sculpture","whatever","made","entertainment","waste","time","tautologically","taking","time","important","stuff","talk","feeling","stuff","live","hunting","gathering","stock","trading","enjoying","nature","happy","living","moment","floor","stupidly","blinded","culture","tradition","job","religion","religion","tradition","stupid","banal","ill","leave","culture","art","today","true","sometimes","enjoy","watching","human","creation","useful","back","thought","thanks","debating","kindly","clear","let","ill","try","specific","p","sorry","mistake","language","native","speaker","language","edit","thanks","meaningful","sleep","call","well","good","debate","culture","art","entertainment","therefore","useless","unnecessary"]|I'll move some arguments forwards and some backwards, so I can explain better. It's a thought that goes further than this, and I've had big arguments with my friends about this. And I'm not against art and culture, is just it's useless.\n\nFirst of all: I'm studying a PhD in Communication, I have a degree in Music (Conservatoire in Trumpet), I can play more than 10 music instruments and I have worked in corporate identity. Now I am a teacher in graphic design, for journalism and advertising.\n\nMy feelings. People who know about Van Gogh or Mozart or any artist, have a lot of useless information, and of course, shouldn't make of or denigrate people who don't know them, or any other artist. Actually, knowing them and their "creations" doesn't make you smarter or even happier. That makes me think why. Why someone should study "culture": literature (novels, poetry), plastic arts, music etc... \n\nCulture is made by the artist to be observed, to express feelings, to rant, to make money and maybe to make us think, but that can be done by trees, rocks, business or books (non fictional).\n\nWhenever someone does not know an important fact or person, even if I know it, or not, and someone laughs or corrects them with disdain, I cringe. Why should they know? What use does it have towards your life, your existence, your happiness?\n\nMost of the information people have about artists, writers or painters, is  ...
# +------------+-----+-----+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 5 rows

# %% [markdown]
# ## 2 – Exploration

# %%
#Getting the count per categories
n2_categorized.groupBy("category_title").count().orderBy("count", ascending=False).show()
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
# +--------------+-----+
# |category_title|count|
# +--------------+-----+
# |       Society|22749|
# |         Other|20176|
# |      Politics|13118|
# |        Gender| 3518|
# |   Environment| 2816|
# |       Culture| 1605|
# |        Health|  396|
# |       Economy|  298|
# |        Sports|  187|
# |       Animals|  122|
# |    Technology|   64|
# |     Education|   55|
# |          Food|   43|
# |    Philosophy|   22|
# +--------------+-----+

# %%
#This shows how our classifier works. Here it talks about Israel-Palestine conflict in 2013.
n2_categorized.filter(col("category_title") == "Politics").show(1, truncate=False)
# Out:
# +------------+-----+-----+----+--------------------+--------------------+----------+--------------+
# |num_comments|score|delta|urls|           processed|              merged|year_month|category_title|
# +------------+-----+-----+----+--------------------+--------------------+----------+--------------+
# |          42|   11|false|  []|["history","confl...|All through histo...|   2013-07|      Politics|
# +------------+-----+-----+----+--------------------+--------------------+----------+--------------+
# only showing top 1 row
# [Stage 6:>                                                          (0 + 1) / 1]

# %% [markdown]
# ## 3 – Feature extraction

# %% [markdown]
# ### 3.1  Pronoun‑use features
#
# We create two linguistic counters that capture how often an author refers to themselves individually versus collectively:
#
# | Column | What it counts | Linguistic intuition |
# |--------|----------------|----------------------|
# | `first_person_singular_count` | Occurrences of **I, me, my, mine** | Signals personal experience, introspection, or ego‑involvement (*“I feel…”, “my view is…”*). |
# | `first_person_plural_count`   | Occurrences of **we, us, our, ours** | Signals group identity, shared responsibility, or coalition framing (*“we should…”, “our society…”*). |
#
# #### Why these features matter
# Research in discourse analysis suggests that **self‑focused language** can convey vulnerability or authenticity, while **collective pronouns** can invoke solidarity and broaden appeal.
# Both strategies may influence persuasion in online debates.
#
# #### How they’re computed (distributed)
# 1. Lower‑case the merged text.
# 2. Tokenise with a simple word‑boundary regex (`\b\w+\b`).
# 3. Tally tokens that belong to the predefined singular or plural pronoun sets.
# 4. Wrap the Python functions as Spark UDFs so counting runs in parallel on every partition.
#
# The resulting integer counts become inputs for the downstream classification model, allowing us to test whether pronoun choice correlates with Δ‑success.

# %%
# Define pronoun sets
first_person_singular_pronouns = {"i", "me", "my", "mine"}
first_person_plural_pronouns = {"we", "us", "our", "ours"}

# Counting functions
def count_first_singular_person(text):
    if not text:
        return 0
    # Normalize and tokenize
    words = re.findall(r"\b\w+\b", text.lower())
    return sum(1 for word in words if word in first_person_singular_pronouns)

def count_first_plural_person(text):
    if not text:
        return 0
    # Normalize and tokenize
    words = re.findall(r"\b\w+\b", text.lower())
    return sum(1 for word in words if word in first_person_plural_pronouns)


# Wrap functions as Spark UDFs
count_fp_udf = udf(count_first_singular_person, IntegerType())
count_fp_plural_udf = udf(count_first_plural_person, IntegerType())

# Augment the DataFrame with new features
df = n2_categorized.withColumn("first_person_singular_count", count_fp_udf(col("merged")))
df = df.withColumn("first_person_plural_count", count_fp_plural_udf(col("merged")))

df.select("first_person_singular_count", "first_person_plural_count").show(1)
# Out:
# [Stage 1:>                                                          (0 + 1) / 1]
# +---------------------------+-------------------------+
# |first_person_singular_count|first_person_plural_count|
# +---------------------------+-------------------------+
# |                          1|                        0|
# +---------------------------+-------------------------+
# only showing top 1 row

# %% [markdown]
# ### 3.2  Length‑based features
#
# We begin with two simple yet informative size metrics:
#
# | Column | Definition | Why it matters |
# |--------|------------|----------------|
# | `post_content_length`  | Number of whitespace‑delimited tokens in the OP’s body (`selftext`). | Longer posts may provide more context or evidence, potentially affecting Δ‑rates. |
# | `title_content_length` | Number of tokens in the headline (`title`). | Extremely short or overly long titles can influence click‑through and engagement. |
#
# Both counts are computed with Spark’s `size(split())`, keeping the operation fully distributed.

# %%
# Augment the DataFrame with new lenght-based features
df = df.withColumn("post_content_length", size(split(col("selftext"), r"\s+")))
df = df.withColumn("title_content_length", size(split(col("title"), r"\s+")))

# %% [markdown]
# ### 3.3  Evidence indicator: `has_url`
#
# A binary flag that equals **1** if the OP contains at least one outbound link and **0** otherwise.
# Links often signal external evidence or citations, which prior work links to higher persuasive power.

# %%
df = df.withColumn(
    "has_url",
    when(size(col("urls")) > 0, lit(1)).otherwise(lit(0))
)

# %% [markdown]
# ### 3.4 Readability feature: Flesch–Kincaid Grade Level
#
# We add a readability score for each post using the Flesch–Kincaid (FK) formula:
#
# **FK Grade** = 0.39 * **ASL** + 11.8 * **ASW** - 15.59
#
#
#
# where
# * **ASL** = average sentence length (words / sentence)
# * **ASW** = average syllables per word
#
# | Interpretation | Typical grade level |
# |----------------|---------------------|
# | **≤ 6**  | Easy / elementary |
# | 7 – 9   | Middle school |
# | 10 – 12 | High school |
# | **> 12** | College and above |
#
# We included readability because persuasion can depend on cognitive load: material that is too complex (high FK) or too simplistic (very low FK) may reduce credibility or engagement.
#
# The score is computed in a UDF that:
#
# 1. Splits the text into sentences.
# 2. Counts words and syllables via regex.
# 3. Applies the FK formula and rounds to two decimals.
#
# Using a Spark UDF keeps the computation parallelised across the cluster.

# %%
# Function to estimate the number of syllables in a single word
def count_syllables(word):
    word = word.lower()
    return max(1, len(re.findall(r'[aeiouy]+', word))) # Count contiguous groups of vowels

# Function to compute the Flesch–Kincaid readability grade for a given text
def fk_grade(text):
    if not text:
        return None
    sentences = re.split(r'[.!?]', text)
    sentences = [s for s in sentences if s.strip()]
    num_sentences = len(sentences)

    # Extract all words using a basic word regex
    words = re.findall(r'\w+', text)
    num_words = len(words)
    syllables = sum(count_syllables(word) for word in words)

    if num_sentences == 0 or num_words == 0:
        return None
    # Compute FK components:
    ASL = num_words / num_sentences  # Average Sentence Length
    ASW = syllables / num_words      # Average Syllables per Word

     # Return Flesch–Kincaid
    return round(0.39 * ASL + 11.8 * ASW - 15.59, 2)

# Register the function as a Spark UDF so it can be applied to a DataFrame column
fk_grade_udf = udf(fk_grade, FloatType())

# %%
df_flesch = df.withColumn("fk_grade", fk_grade_udf(n2_categorized["merged"]))
df_flesch.show(4)
# Out:
# [Stage 2:>                                                          (0 + 1) / 1]
# +------------+-----+-----+-----------+--------------------+--------------------+----------+--------------+--------------------+--------------------+---------------------------+-------------------------+-------------------+--------------------+-------+--------+
# |num_comments|score|delta|       urls|           processed|              merged|year_month|category_title|               title|            selftext|first_person_singular_count|first_person_plural_count|post_content_length|title_content_length|has_url|fk_grade|
# +------------+-----+-----+-----------+--------------------+--------------------+----------+--------------+--------------------+--------------------+---------------------------+-------------------------+-------------------+--------------------+-------+--------+
# |           1|    1|false|         []|["apple","product...| I believe that A...|   2013-07|       Culture|I believe that Ap...|                    |                          1|                        0|                  1|                  12|      0|    8.38|
# |           2|    2|false|[imgur.com]|["every","single"...|Every single year...|   2013-10|       Society|CMV I Believe We ...|Every single year...|                          8|                        1|                100|                  13|      1|    5.57|
# |          44|   22|false|         []|["instance","girl...|For instance, gir...|   2013-09|        Gender|I believe many fe...|For instance, gir...|                          5|                        1|                117|                  20|      0|   10.81|
# |          30|   22|false|         []|["everyone","alre...|Everyone already ...|      NULL|         Other|CMV: Teaching abs...|Everyone already ...|                          1|                        1|                 94|                  20|      0|   10.06|
# +------------+-----+-----+-----------+--------------------+--------------------+----------+--------------+--------------------+--------------------+---------------------------+-------------------------+-------------------+--------------------+-------+--------+
# only showing top 4 rows

# %%
# Display posts with very low Flesch–Kincaid Grade Level
df_flesch.filter(col("fk_grade") < 4).show(5, truncate=False)
# Out:
# [Stage 3:>                                                          (0 + 1) / 1]
# +------------+-----+-----+----+------------------------------+-----------------------------------------+----------+--------------+----------------------------------------+--------+---------------------------+-------------------------+-------------------+--------------------+-------+--------+
# |num_comments|score|delta|urls|processed                     |merged                                   |year_month|category_title|title                                   |selftext|first_person_singular_count|first_person_plural_count|post_content_length|title_content_length|has_url|fk_grade|
# +------------+-----+-----+----+------------------------------+-----------------------------------------+----------+--------------+----------------------------------------+--------+---------------------------+-------------------------+-------------------+--------------------+-------+--------+
# |32          |48   |false|[]  |["self","post","karma"]       | I think self posts should get karma. CMV|2013-05   |Other         |I think self posts should get karma. CMV|        |1                          |0                        |1                  |8                   |0      |-0.75   |
# |1           |0    |false|[]  |["dick"]                      | i like dick.                            |NULL      |Gender        |i like dick.                            |        |1                          |0                        |1                  |3                   |0      |1.31    |
# |1           |1    |false|[]  |["v"]                         | ABC vs. ESPN                            |NULL      |Politics      |ABC vs. ESPN                            |        |0                          |0                        |1                  |3                   |0      |-3.2    |
# |1           |1    |false|[]  |["text","thread","need","tag"]| CMV: Text threads don't need NSFW tags. |NULL      |Culture       |CMV: Text threads don't need NSFW tags. |        |0                          |0                        |1                  |7                   |0      |-0.67   |
# |1           |1    |false|[]  |["bad"]                       | I dont feel bad for fatshaming. CMV     |2013-10   |Other         |I dont feel bad for fatshaming. CMV     |        |1                          |0                        |1                  |7                   |0      |0.95    |
# +------------+-----+-----+----+------------------------------+-----------------------------------------+----------+--------------+----------------------------------------+--------+---------------------------+-------------------------+-------------------+--------------------+-------+--------+
# only showing top 5 rows

# %% [markdown]
# ### 3.5 Sentiment Analysis with VADER
#
# We enrich our dataset with a sentiment score using the **VADER (Valence Aware Dictionary and sEntiment Reasoner)** tool from NLTK, which is well-suited for analyzing social media and informal online text.
#
# #### What we compute:
# - **Compound score**: A normalized value ranging from -1 (very negative) to +1 (very positive).
# - We apply the sentiment model to the entire post (`title + selftext`) using a Spark UDF.
#
# #### Why compound only?
# Although VADER also outputs separate scores for positive, neutral, and negative sentiment, we focus on the **compound** score since it summarizes the overall emotional tone in a single interpretable metric:
# - `x > 0.5` → positive
# - `-0.5 < x < 0.5` → neutral
# - `x < -0.5` → negative
#
# This feature allows us to test whether emotionally charged posts correlate with persuasion outcomes or differ across topic categories.

# %%
# Define UDF for compound sentiment score
def get_vader_compound(text):
    if text:
        analyzer = SentimentIntensityAnalyzer()
         # VADER returns a dictionary with 'neg', 'neu', 'pos', and 'compound' scores
        return float(analyzer.polarity_scores(text)['compound'])
    return 0.0 # Default to neutral if text is missing

# Register the UDF with Spark
vader_udf = udf(get_vader_compound, FloatType())
df_sentiment = df_flesch.withColumn("sentiment", vader_udf(col("merged")))

# Display the sentiment scores alongside the post text
df_sentiment.select("merged", "sentiment").show(5, truncate=False)
# Out:
# [Stage 4:>                                                          (0 + 1) / 1]
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |merged                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# | I believe that Apple products are far superior to Microsoft products. CMV.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# |Every single year I think to myself, "There couldn't possibly be anything left to 'pinkify'." but then the next year roles around and another master of marketing finds something else . Don't get me wrong, I'm a guy that has many "pink" shirts, so it's not that I dislike the color pink. It's just when will it stop? This year it was the pink flags that the NFL Referees are using now. After that I began to wonder, "What could possibly be left for them to 'pinkify' now?". Well, today I was given this. Here is my [Walgreens prescription bottle.](http://imgur.com/bVfhW5E) CMV I Believe We Have Taken PINK for Breast Cancer Awareness Too Far                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# |For instance, girls complain when guys check them out saying we're pigs, when that's just human instinct, to judge attractiveness and when a woman does it, it's totally fine. Let me make it clear, I am of course for equality of the sexes, I just think feminists(not all) should focus on other things and not assume things about what men do, like think that when a guy holds open the door for her that he's coddling her cause she's "too weak". As if they can't just be being nice. Also, I think feminism should also take some things unfair to men into consideration such as custody of children and abuse, whether physical or verbal, towards men. CMV I believe many feminists look way too much into things men do and dont focus enough on actual problems. CMV                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |Everyone already knows that they can not have sex. Not having sex is the default option for a person. But one of the strongest (if not THE strongest) natural urge we have is the urge to have sex. You're not going to stop it from happening, even with this whole christian purity culture bullshit making kids ashamed of their natural urges you cant stop it from happening.\n\nThe only logical thing to do is to teach people how to do it safely and avoid pregnancy if/when they decide they're going to do it.\n\n CMV: Teaching abstinence instead of safe sex in high school health class is useless and to me, ridiculous and asinine.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |I'll move some arguments forwards and some backwards, so I can explain better. It's a thought that goes further than this, and I've had big arguments with my friends about this. And I'm not against art and culture, is just it's useless.\n\nFirst of all: I'm studying a PhD in Communication, I have a degree in Music (Conservatoire in Trumpet), I can play more than 10 music instruments and I have worked in corporate identity. Now I am a teacher in graphic design, for journalism and advertising.\n\nMy feelings. People who know about Van Gogh or Mozart or any artist, have a lot of useless information, and of course, shouldn't make of or denigrate people who don't know them, or any other artist. Actually, knowing them and their "creations" doesn't make you smarter or even happier. That makes me think why. Why someone should study "culture": literature (novels, poetry), plastic arts, music etc... \n\nCulture is made by the artist to be observed, to express feelings, to rant, to make money and maybe to make us think, but that can be done by trees, rocks, business or books (non fictional).\n\nWhenever someone does not know an important fact or person, even if I know it, or not, and someone laughs or corrects them with disdain, I cringe. Why should they know? What use does it have towards your life, your existence, your happiness?\n\nMost of the information people have about artists, writers or painters, is useless, and it's not better than knowing sports or the number of tiles in your street. This is pretty clear for me. But what is the use of culture? What if we hadn't had great artists? We could still be happy and live plenty with nature, ourselves, our beloved ones...\n\n\nCounterpoint 1 (from my friends). They say you can feel, learn or whatever art does to you, it can be done with natural things, and even better, stronger, harder, deeper... And I think, but we don't need to "manufacture" fake feelings that can be naturally felt (true relationships, friendship, love, staring at a mountain...). That makes culture as a whole look artificial.\n\nCounterpoint 2: They influence on us, on our physical design of other useful stuff (buildings, decoration...)... Yeah, so do other stuff, but we can avoid it. Racism influenced art, and that art influenced our designs, so what? How is this an argument? If something has influence, doesn't mean this influence is necessary or even expressly good for the design. It could be counterproductive. I could also do drugs or hit my head against the wall.\n\nIt does not influence on us more than other stuff. It just can affect, like a rainy day or a solar storm. Still, as inspiration goes, you don't need to listen to "creative" music to be inspired to create a nice table design. And why is it good? It just "is".\n\nCounterpoint 3. Art can be enjoyed. Yes, you can also enjoy killing people or watching a lion eat a little gazelle, but I think we can avoid art as much as we can avoid sports if you get me. We don't need them. We don't need to give money to see it, we shouldn't. Movies, games, paintings, comics, sculptures... Even more, whatever is made to be an "entertainment" is a waste of time (tautologically) because it is taking time from your other important stuff: being with your people, talk about feelings, about the stuff we do to live (from hunting and gathering, to stock trading) or enjoying nature itself. We can be happy living the moment with ourselves against the floor, but we are stupidly blinded by culture, tradition, jobs and religion.\n\nI could go further against religions and traditions (I think all of them are stupid and banal) but I'll leave it against culture and art for today.\n\nStill, I myself think this, I think is true, but sometimes I enjoy watching human creations and thinking "how did they come up with this", but then I think "it's not useful" and go back to my thoughts.\n\nThanks for debating kindly, and please, if something is not clear, let me know I'll try to be more specific ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 5 rows

# %% [markdown]
# ### 4 - Upload to bucket
#
#
# This output will be used as input for Notebooks 04 and 05.

# %%
n3_features_df = df_sentiment

# %%
n3_features_df.write \
         .mode("overwrite") \
         .option("header", "true") \
         .json("gs://st446-cmv/n3_features_df/")
